# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
df=pd.read_excel(r"C:\Users\Aparna\Downloads\nearest_neighbour matching.xlsx")
r=df["P"]
df["P"].min()
df["P"].max()
y=df["pdyno"]
z=(df["P"]-df["P"].min())/(df["P"].max()-df["P"].min())
h=z.to_list()
h=z.to_list()
y2=df["IP Power"]
r=df["Q"]
df["Q"].min()
df["Q"].max()
z=(df["Q"]-df["Q"].min())/(df["Q"].max()-df["Q"].min())
i=z.to_list()
fig= plt.figure(figsize=(10,9))
plt.plot(h,y)
plt.plot(i,y2)

# %%
from scipy.interpolate import interp1d
fig= plt.figure(figsize=(10,9))
fun = interp1d(x=h, y=y)
x3 = np.linspace(start=0, stop=9, num=300)
y3 = fun(x3)
fig= plt.figure(figsize=(10,9))
fun = interp1d(x=i, y=y2)
x0 = np.linspace(start=0, stop=9, num=300)
y0 = fun(x0)
fig= plt.figure(figsize=(10,9))
plt.plot(x0,y0)
plt.plot(x3,y3)

# %%
h=np.linspace(0,1,300)
def interpolate(xval, df, xcol, ycol):
# compute xval as the linear interpolation of xval where df is a dataframe and
#  df.x are the x coordinates, and df.y are the y coordinates. df.x is expected to be sorted.
    return np.interp([xval], df[xcol], df[ycol])
u=np.interp([h], x0,y0)
dfl = pd.DataFrame(u)
dfl.to_excel(r"C:\Users\Aparna\Downloads\a3.xlsx")

# %%
df=pd.read_csv(r"C:\Users\Aparna\Downloads\a1.csv")

# %%
s=df["x"]
t=df['PA_input']
fig= plt.figure(figsize=(15,12))
plt.plot(s,t)
plt.stem(t,linefmt ='yo')
# Out:
# <StemContainer object of 3 artists>

# %%
h=np.linspace(0,1,300)
def interpolate(xval, df, xcol, ycol):
# compute xval as the linear interpolation of xval where df is a dataframe and
#  df.x are the x coordinates, and df.y are the y coordinates. df.x is expected to be sorted.
    return np.interp([xval], df[xcol], df[ycol])
u=np.interp([h], x3,y3)
df = pd.DataFrame(u)
df.to_excel(r"C:\Users\Aparna\Downloads\a3.xlsx")

# %%
dfy=pd.read_csv(r"C:\Users\Aparna\Downloads\a1.csv")
h=dfy["P_DYNO"]
k=dfy["x"]
fig= plt.figure(figsize=(15,12))
plt.plot(k,h)
plt.stem(h)
# Out:
# <StemContainer object of 3 artists>

# %%
import pandas as pd
import matplotlib.pyplot as plt
dfq=pd.read_excel(r"C:\Users\Aparna\Downloads\matching_raw_velocity.xlsx")
r=dfq["X"]
dfq["X"].min()
dfq["X"].max()
z=(dfq["X"]-dfq["X"].min())/(dfq["X"].max()-dfq["X"].min())
h=z.to_list()
d=dfq["POUT"]
e=dfq["v Dyno"]

# %%
from scipy.interpolate import interp1d
fig= plt.figure(figsize=(10,9))
fun = interp1d(x=h, y=e)
x3 = np.linspace(start=0, stop=1, num=300)
y3 = fun(x3)

# %%
h=np.linspace(0,1,300)
def interpolate(xval, df, xcol, ycol):
# compute xval as the linear interpolation of xval where df is a dataframe and
#  df.x are the x coordinates, and df.y are the y coordinates. df.x is expected to be sorted.
    return np.interp([xval], df[xcol], df[ycol])
u=np.interp([h], x3,y3)
df = pd.DataFrame(u)
df.to_excel(r"C:\Users\Aparna\Downloads\a3.xlsx")

# %%
dft=pd.read_csv(r"C:\Users\Aparna\Downloads\a1.csv")

# %%
m=dft["x"]
n=dft["velocity"]

# %%
fig= plt.figure(figsize=(10,6))
plt.plot(m,n)
plt.xlim(0,300)
plt.stem(n,linefmt ='g')
# Out:
# <StemContainer object of 3 artists>

# %%
plt.plot(x1,y1)
plt.plot(x,y)
plt.stem(y1,linefmt ='r',basefmt=" ")
plt.stem(y,linefmt ='yo')
plt.plot(m,n)
plt.stem(n,linefmt ='g')
# Out:
# <StemContainer object of 3 artists>

# %%
fig, ax1 = plt.subplots(figsize=(15, 10))
ax2 = ax1.twinx()
ax1.plot(x1,y1,label="pdyno",color="purple",linewidth=3)
ax1.plot(x,y,label="power analyzer",color="g",linewidth=3)
ax1.stem(y1,linefmt ='g',basefmt=" ")
ax1.stem(y,linefmt ='o')
ax2.plot(m,n,color="red",linewidth=3)
ax1.set_xlim(0,96)
ax2.stem(n,linefmt ='r',basefmt=" ")
# Out:
# <StemContainer object of 3 artists>

# %%
dfy.columns
# Out:
# Index(['x', 'Pa_input', 'Pdyno', 'm/s', 'velocity', 'PA_input', 'P_Dyno'], dtype='object')

# %%
fig= plt.figure(figsize=(10,6))
plt.plot(m,n)
plt.xlim(0,300)
plt.stem(n,linefmt ='g')
# Out:
# <StemContainer object of 3 artists>

# %%
fig= plt.figure(figsize=(10,6))
plt.plot(s,t)
plt.stem(t,linefmt ='yo')
# Out:
# <StemContainer object of 3 artists>

# %%
plt.plot(k,h)
plt.stem(h)
# Out:
# <StemContainer object of 3 artists>

# %%
fig, ax1 = plt.subplots(figsize=(15, 10))
ax2 = ax1.twinx()
ax1.plot(s,t,label="pdyno",color="purple",linewidth=3)
ax1.plot(k,h,label="power analyzer",color="g",linewidth=3)
ax1.stem(t,linefmt ='g',basefmt=" ")
ax1.stem(h,linefmt ='o')
ax2.plot(m,n,color="red",linewidth=3)
ax2.stem(n,linefmt ='r',basefmt=" ")
ax1.set_xlim(0,285)
# Out:
# (0.0, 285.0)
