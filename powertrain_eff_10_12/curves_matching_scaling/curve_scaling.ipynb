# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
df=pd.read_excel(r"C:\Users\Aparna\Downloads\nearest_neighbour matching.xlsx")
r=df["P"]
df["P"].min()
df["P"].max()
y=df["pdyno"]
z=(df["P"]-df["P"].min())/(df["P"].max()-df["P"].min())
h=z.to_list()
h=z.to_list()
y2=df["IP Power"]
r=df["Q"]
df["Q"].min()
df["Q"].max()
z=(df["Q"]-df["Q"].min())/(df["Q"].max()-df["Q"].min())
i=z.to_list()
fig= plt.figure(figsize=(10,9))
plt.plot(h,y)
plt.plot(i,y2)

# %%
from scipy.interpolate import interp1d
fig= plt.figure(figsize=(10,9))
fun = interp1d(x=h, y=y)
x3 = np.linspace(start=0, stop=9, num=300)
y3 = fun(x3)
fig= plt.figure(figsize=(10,9))
fun = interp1d(x=i, y=y2)
x0 = np.linspace(start=0, stop=9, num=300)
y0 = fun(x0)
fig= plt.figure(figsize=(10,9))
plt.plot(x0,y0)
plt.plot(x3,y3)

# %%
h=np.linspace(0,1,100)
def interpolate(xval, df, xcol, ycol):
# compute xval as the linear interpolation of xval where df is a dataframe and
#  df.x are the x coordinates, and df.y are the y coordinates. df.x is expected to be sorted.
    return np.interp([xval], df[xcol], df[ycol])
u=np.interp([h], x0,y0)
df = pd.DataFrame(u)

# %%
df=pd.read_csv(r"C:\Users\Aparna\Downloads\a1.csv")
x=df["x"]
y=df["Pa_input"]
fig= plt.figure(figsize=(15,12))
plt.plot(x,y)
plt.stem(y,linefmt ='yo')
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# c:\Users\Aparna\Desktop\Power_Train\powertrain_eff_10_12\curves_matching_scaling\curve_scaling.ipynb Cell 4 in <cell line: 1>()
# ----> <a href='vscode-notebook-cell:/c%3A/Users/Aparna/Desktop/Power_Train/powertrain_eff_10_12/curves_matching_scaling/curve_scaling.ipynb#W3sZmlsZQ%3D%3D?line=0'>1</a> df=pd.read_csv(r"C:\Users\Aparna\Downloads\a1.csv")
#       <a href='vscode-notebook-cell:/c%3A/Users/Aparna/Desktop/Power_Train/powertrain_eff_10_12/curves_matching_scaling/curve_scaling.ipynb#W3sZmlsZQ%3D%3D?line=1'>2</a> x=df["x"]
#       <a href='vscode-notebook-cell:/c%3A/Users/Aparna/Desktop/Power_Train/powertrain_eff_10_12/curves_matching_scaling/curve_scaling.ipynb#W3sZmlsZQ%3D%3D?line=2'>3</a> y=df["Pa_input"]
#
# File c:\Users\Aparna\anaconda3\lib\site-packages\pandas\util\_decorators.py:311, in deprecate_nonkeyword_arguments.<locals>.decorate.<locals>.wrapper(*args, **kwargs)
#     305 if len(args) > num_allow_args:
#     306     warnings.warn(
#     307         msg.format(arguments=arguments),
#     308         FutureWarning,
#     309         stacklevel=stacklevel,
#     310     )
# --> 311 return func(*args, **kwargs)
#
# File c:\Users\Aparna\anaconda3\lib\site-packages\pandas\io\parsers\readers.py:680, in read_csv(filepath_or_buffer, sep, delimiter, header, names, index_col, usecols, squeeze, prefix, mangle_dupe_cols, dtype, engine, converters, true_values, false_values, skipinitialspace, skiprows, skipfooter, nrows, na_values, keep_default_na, na_filter, verbose, skip_blank_lines, parse_dates, infer_datetime_format, keep_date_col, date_parser, dayfirst, cache_dates, iterator, chunksize, compression, thousands, decimal, lineterminator, quotechar, quoting, doublequote, escapechar, comment, encoding, encoding_errors, dialect, error_bad_lines, warn_bad_lines, on_bad_lines, delim_whitespace, low_memory, memory_map, float_precision, storage_options)
#     665 kwds_defaults = _refine_defaults_read(
#     666     dialect,
#     667     delimiter,
#    (...)
#     676     defaults={"delimiter": ","},
#     677 )
#     678 kwds.update(kwds_defaults)
# --> 680 return _read(filepath_or_buffer, kwds)
#
# File c:\Users\Aparna\anaconda3\lib\site-packages\pandas\io\parsers\readers.py:575, in _read(filepath_or_buffer, kwds)
#     572 _validate_names(kwds.get("names", None))
#     574 # Create the parser.
# --> 575 parser = TextFileReader(filepath_or_buffer, **kwds)
#     577 if chunksize or iterator:
#     578     return parser
#
# File c:\Users\Aparna\anaconda3\lib\site-packages\pandas\io\parsers\readers.py:933, in TextFileReader.__init__(self, f, engine, **kwds)
#     930     self.options["has_index_names"] = kwds["has_index_names"]
#     932 self.handles: IOHandles | None = None
# --> 933 self._engine = self._make_engine(f, self.engine)
#
# File c:\Users\Aparna\anaconda3\lib\site-packages\pandas\io\parsers\readers.py:1217, in TextFileReader._make_engine(self, f, engine)
#    1213     mode = "rb"
#    1214 # error: No overload variant of "get_handle" matches argument types
#    1215 # "Union[str, PathLike[str], ReadCsvBuffer[bytes], ReadCsvBuffer[str]]"
#    1216 # , "str", "bool", "Any", "Any", "Any", "Any", "Any"
# -> 1217 self.handles = get_handle(  # type: ignore[call-overload]
#    1218     f,
#    1219     mode,
#    1220     encoding=self.options.get("encoding", None),
#    1221     compression=self.options.get("compression", None),
#    1222     memory_map=self.options.get("memory_map", False),
#    1223     is_text=is_text,
#    1224     errors=self.options.get("encoding_errors", "strict"),
#    1225     storage_options=self.options.get("storage_options", None),
#    1226 )
#    1227 assert self.handles is not None
#    1228 f = self.handles.handle
#
# File c:\Users\Aparna\anaconda3\lib\site-packages\pandas\io\common.py:789, in get_handle(path_or_buf, mode, encoding, compression, memory_map, is_text, errors, storage_options)
#     784 elif isinstance(handle, str):
#     785     # Check whether the filename is to be opened in binary mode.
#     786     # Binary mode does not support 'encoding' and 'newline'.
#     787     if ioargs.encoding and "b" not in ioargs.mode:
#     788         # Encoding
# --> 789         handle = open(
#     790             handle,
#     791             ioargs.mode,
#     792             encoding=ioargs.encoding,
#     793             errors=errors,
#     794             newline="",
#     795         )
#     796     else:
#     797         # Binary mode
#     798         handle = open(handle, ioargs.mode)
#
# FileNotFoundError: [Errno 2] No such file or directory: 'C:\\Users\\Aparna\\Downloads\\a1.csv'

# %%
h=np.linspace(0,1,100)
def interpolate(xval, df, xcol, ycol):
# compute xval as the linear interpolation of xval where df is a dataframe and
#  df.x are the x coordinates, and df.y are the y coordinates. df.x is expected to be sorted.
    return np.interp([xval], df[xcol], df[ycol])
u=np.interp([h], x3,y3)
df = pd.DataFrame(u)
df=pd.read_csv(r"C:\Users\Aparna\Downloads\a1.csv")
y1=df["Pdyno"]
x1=df["x"]

# %%
fig= plt.figure(figsize=(15,12))
plt.legend(['Power AnalyzerI/P'])
plt.plot(x1,y1)
plt.plot(x,y)
plt.stem(y1,linefmt ='r',basefmt=" ")
plt.stem(y,linefmt ='yo')
# Out:
# <StemContainer object of 3 artists>

# %%
import pandas as pd
import matplotlib.pyplot as plt
dfq=pd.read_excel(r"C:\Users\Aparna\Downloads\matching_raw_velocity.xlsx")
r=dfq["X"]
dfq["X"].min()
dfq["X"].max()
z=(dfq["X"]-dfq["X"].min())/(dfq["X"].max()-dfq["X"].min())
h=z.to_list()
d=dfq["POUT"]
e=dfq["v Dyno"]

# %%
from scipy.interpolate import interp1d
fig= plt.figure(figsize=(10,9))
fun = interp1d(x=h, y=e)
x3 = np.linspace(start=0, stop=1, num=300)
y3 = fun(x3)

# %%
h=np.linspace(0,1,100)
def interpolate(xval, df, xcol, ycol):
# compute xval as the linear interpolation of xval where df is a dataframe and
#  df.x are the x coordinates, and df.y are the y coordinates. df.x is expected to be sorted.
    return np.interp([xval], df[xcol], df[ycol])
u=np.interp([h], x3,y3)
df = pd.DataFrame(u)
df.to_excel(r"C:\Users\Aparna\Downloads\a3.xlsx")

# %%
dft=pd.read_csv(r"C:\Users\Aparna\Downloads\a1.csv")

# %%
m=dft["x"]
n=dft["m/s"]

# %%
fig= plt.figure(figsize=(15,12))
plt.plot(m,n)
plt.stem(n,linefmt ='g')
# Out:
# <StemContainer object of 3 artists>

# %%
fig, ax1 = plt.subplots(figsize=(15, 10))
ax2 = ax1.twinx()
ax1.plot(x1,y1,label="pdyno",color="purple",linewidth=3)
ax1.plot(x,y,label="power analyzer",color="g",linewidth=3)
ax1.stem(y1,linefmt ='g',basefmt=" ")
ax1.stem(y,linefmt ='o')
ax2.plot(m,n,color="red",linewidth=3)
ax1.set_xlim(0,96)
ax2.stem(n,linefmt ='r',basefmt=" ")
# Out:
# <StemContainer object of 3 artists>
