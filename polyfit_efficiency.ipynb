# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
import sys

# %%
dataset = pd.read_csv(r'/content/a1.csv')
dataset.fillna(0,inplace=True)
X = dataset.iloc[:, :-1].values
y = dataset.iloc[:, -1].values

# %%
y
# Out:
# array([ 1.34138162, 31.46920515,  4.09500719,  4.61834274,  4.30390924,
#         5.06644978,  6.12271205,  6.95993409,  7.77427805,  8.60555074,
#         8.96574739,  9.32594404, 10.03495991, 11.29639642, 12.47595037,
#        13.27609335, 13.88226579, 14.35594821, 14.53032836, 15.72208249,
#        16.61792542, 17.27022664, 18.4325929 , 19.7572343 , 21.09487963,
#        22.98498756, 24.85113363, 26.71727971, 28.58342578, 28.29128332,
#        27.91293726, 27.53459121, 27.15624515, 26.53115606, 25.73378606,
#        24.93641605, 24.13904605, 24.24363162, 25.14991401, 26.05619641,
#        26.97525693, 28.03262515, 29.08999337, 30.14736159, 31.72452604,
#        33.73718269, 35.74983934, 37.76249599, 39.43093187, 40.78270495,
#        42.13447803, 43.48625111, 44.83802419, 45.53097281, 45.86542697,
#        46.19988114, 46.5343353 , 46.86878946, 46.96666444, 46.40028093,
#        45.83389742, 45.26751391, 44.7011304 , 44.13474689, 43.56836337,
#        43.00197986, 42.43559635, 42.35506205, 42.69426194, 43.11276641,
#        43.53127087, 43.94977533, 44.34746251, 44.73326971, 45.11907692,
#        45.50488412, 46.04989895, 46.62634612, 47.2027933 , 47.78922078,
#        48.48652123, 49.18382169, 49.88112215, 50.51700643, 51.01408739,
#        51.51116835, 52.0082493 , 52.37822946, 52.60340235, 52.82857523,
#        53.05374812, 53.26662365, 53.47191385, 53.67720406, 53.88249427,
#        54.26889614, 54.69181254, 55.11472895, 55.51351928, 55.698425  ,
#        55.88333071, 56.06823643, 56.25314215, 56.43804787, 56.62295358,
#        56.57172956, 56.73416854, 57.01137494, 57.28858133, 57.61542286,
#        58.05983755, 58.50425225, 58.94866695, 58.75786817, 58.45105745,
#        58.14424672, 58.16890774, 58.57866901, 58.98843028, 59.30017543,
#        59.19959997, 59.09902451, 58.99844905, 58.86764158, 58.73632388,
#        58.60500618, 59.15099627, 59.77964576, 60.40829526, 60.46765349,
#        60.45129656, 60.43493963, 60.34959264, 60.25558394, 60.16157524,
#        60.06756654, 59.97355783, 59.83686205, 59.64812622, 59.45939039,
#        59.33463917, 59.29045936, 59.24627955, 59.96189829, 60.86043282,
#        61.39258675, 60.5148562 , 59.63712564, 60.0931653 , 61.31161893,
#        62.26811351, 61.63946783, 61.01082216, 61.19979805, 61.85649516,
#        62.14371556, 61.01309761, 59.88247966, 60.03028708, 60.47588382,
#        60.92148055, 61.36707729, 61.61129543, 61.49217126, 61.41059446,
#        62.35054861, 63.29050276, 63.26963108, 63.01047403, 62.71384313,
#        62.38628187, 61.83485451, 60.87315388, 60.26659785, 60.72660401,
#        60.97811852, 60.43400248, 60.03529475, 60.24858821, 60.48572488,
#        60.79713603, 61.10854717, 61.41995832, 61.98854458, 62.33294024,
#        62.54910693, 62.60171717, 63.24867727, 64.39644471, 64.31921747,
#        63.57292138, 62.80040691, 62.01826993, 61.75181678, 61.65502865,
#        62.3683153 , 62.58402134, 61.92808971, 61.74134898, 61.83526355,
#        61.92917812, 61.43802481, 61.79169648, 62.48513659, 63.40752969,
#        63.09930172, 62.98515895, 63.37136656, 63.12100591, 62.66650862,
#        62.66588067, 62.54506127, 62.34494903, 62.8523642 , 63.2897199 ,
#        63.66044158, 64.03116326, 64.35298865, 62.79220948, 61.39069242,
#        62.48403322, 64.80055629, 63.28448057, 62.7539515 , 62.9698413 ,
#        63.87366912, 62.86742293, 64.24638014, 65.61896571, 63.55298061,
#        61.55016478, 65.17447341, 65.02744985, 63.72647273, 63.43282065,
#        62.49336154, 62.25962592, 61.76127718, 63.23208588, 62.60198836,
#        61.16031486, 60.03632213, 56.47378091, 60.02452883, 63.0060386 ,
#        60.90601868, 58.41864125, 59.00584623, 56.67554458, 55.63367626,
#        54.812797  , 53.2590927 , 53.94904102, 51.44604429, 51.28185163,
#        48.43539206, 48.43539206, 48.43539206, 48.43539206, 48.43539206,
#        48.43539206, 48.43539206, 48.43539206, 48.43539206, 48.43539206,
#        48.43539206, 48.43539206, 48.43539206, 48.43539206, 48.43539206,
#        48.43539206, 48.43539206, 48.43539206, 48.43539206, 48.43539206,
#        48.43539206, 48.43539206, 48.43539206, 48.43539206, 48.43539206,
#        48.43539206, 48.43539206, 48.43539206, 48.43539206, 48.43539206,
#        48.43539206, 48.43539206, 48.43539206, 48.43539206, 48.43539206,
#        48.43539206, 48.43539206, 48.43539206, 48.43539206, 48.43539206,
#        48.43539206, 48.43539206, 48.43539206, 48.43539206, 48.43539206])

# %%
from sklearn.linear_model import LinearRegression
lin_reg = LinearRegression()
lin_reg.fit(X, y)
# Out:
# LinearRegression()

# %%
from sklearn.preprocessing import PolynomialFeatures
poly_reg = PolynomialFeatures(degree = 9)
X_poly = poly_reg.fit_transform(X)
lin_reg_2 = LinearRegression()
lin_reg_2.fit(X_poly, y)
# Out:
# LinearRegression()

# %%
plt.scatter(X, y, color = 'red')
plt.plot(X, lin_reg.predict(X), color = 'blue')
plt.title('efficiency Vs Velocity (Linear Regression)')
plt.xlabel('Velocity')
plt.ylabel('Efficiency')
plt.show()

# %%
plt.scatter(X, y, color = 'red')
plt.plot(X, lin_reg_2.predict(poly_reg.fit_transform(X)), color = 'blue')
plt.title('efficiency Vs Velocity (Linear Regression)')
plt.xlabel('Velocity')
plt.ylabel('Efficiency')
plt.show()

# %%
X_grid = np.arange(min(X), max(X), 0.1)
X_grid = X_grid.reshape((len(X_grid), 1))
plt.scatter(X, y, color = 'red')
plt.plot(X_grid, lin_reg_2.predict(poly_reg.fit_transform(X_grid)), color = 'blue')
plt.title('efficiency Vs Velocity (Linear Regression)')
plt.xlabel('Velocity')
plt.ylabel('Efficiency')
plt.show()

# %%
df= pd.read_excel(r"/content/final predicted efficiency from IDC velocity_poly regression.xlsx")
df.fillna(0,inplace=True)
y=df["Velocity"].values
x = df['Velocity'].to_numpy()
predict_me = x
predict_me = predict_me.reshape(-1,1)
y_pred = lin_reg.predict(predict_me)
y_pred1=lin_reg_2.predict(poly_reg.fit_transform(predict_me))
e_dataframe = pd.DataFrame(y_pred1)

# %%
e_dataframe.to_excel(r"/content/velocity_IDC_Efficiency.xlsx")

# %%
from google.colab import drive
drive.mount('/content/drive')

# %%
y_pred1=lin_reg_2.predict(poly_reg.fit_transform([[3.78]]))

# %%
y_pred = lin_reg.predict([[3.78]])
y_pred1
# Out:
# array([24.87346945])

# %%
df= pd.read_excel(r"/content/Velocity_IDC.xlsx")

# %%
df1=df[df['Vehicle speed ']<25]
df1.to_excel(r"/content/Velocity_IDC.xlsx")

# %%
import matplotlib.pyplot as plt
fig= plt.figure(figsize=(22,7))
y=df["efficency_IDC"]
plt.xlim(70)
plt.plot(y)
plt.plot(y1)

# %%
fig= plt.figure(figsize=(22,7))
y1=df["predicted_efficiency"]
plt.plot(y1)

# %%
r2_deg2 = r2_score(y, y_deg2)
